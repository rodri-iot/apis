# %%
# INSTALATIONS
# pip install requests python-dotenv
# pip install requests python-dotenv pandas seaborn ipykernel nbformat
# pip freeze > requirements.txt
# pip install spotipy

# API
# https://open-meteo.com

# %%
# Import libraries
import requests
import pandas as pd
import matplotlib.pyplot as plt
# Aditionals for spotipy
import os
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# URL
url = "https://api.open-meteo.com/v1/forecast"
# Def parameters
params = {
    'latitude': 52.52,
    'longitude': 13.41,
    'hourly': 'temperature_2m'
}
response = requests.get(url, params)

# %%
# Check connection
response
# Out:
# <Response [200]>

# %%
# Get json with data of response
response.json()
# Out:
# {'latitude': 52.52,
#  'longitude': 13.419998,
#  'generationtime_ms': 0.07200241088867188,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 38.0,
#  'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C'},
#  'hourly': {'time': ['2024-09-26T00:00',
#    '2024-09-26T01:00',
#    '2024-09-26T02:00',
#    '2024-09-26T03:00',
#    '2024-09-26T04:00',
#    '2024-09-26T05:00',
#    '2024-09-26T06:00',
#    '2024-09-26T07:00',
#    '2024-09-26T08:00',
#    '2024-09-26T09:00',
#    '2024-09-26T10:00',
#    '2024-09-26T11:00',
#    '2024-09-26T12:00',
#    '2024-09-26T13:00',
#    '2024-09-26T14:00',
#    '2024-09-26T15:00',
#    '2024-09-26T16:00',
#    '2024-09-26T17:00',
#    '2024-09-26T18:00',
#    '2024-09-26T19:00',
#    '2024-09-26T20:00',
#    '2024-09-26T21:00',
#    '2024-09-26T22:00',
#    '2024-09-26T23:00',
#    '2024-09-27T00:00',
#    '2024-09-27T01:00',
#    '2024-09-27T02:00',
#    '2024-09-27T03:00',
# ...

# %%
data = response.json()

# %%
# Check type of data
type(data)
# Out:
# dict

# %%
data
# Out:
# {'latitude': 52.52,
#  'longitude': 13.419998,
#  'generationtime_ms': 0.07200241088867188,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 38.0,
#  'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C'},
#  'hourly': {'time': ['2024-09-26T00:00',
#    '2024-09-26T01:00',
#    '2024-09-26T02:00',
#    '2024-09-26T03:00',
#    '2024-09-26T04:00',
#    '2024-09-26T05:00',
#    '2024-09-26T06:00',
#    '2024-09-26T07:00',
#    '2024-09-26T08:00',
#    '2024-09-26T09:00',
#    '2024-09-26T10:00',
#    '2024-09-26T11:00',
#    '2024-09-26T12:00',
#    '2024-09-26T13:00',
#    '2024-09-26T14:00',
#    '2024-09-26T15:00',
#    '2024-09-26T16:00',
#    '2024-09-26T17:00',
#    '2024-09-26T18:00',
#    '2024-09-26T19:00',
#    '2024-09-26T20:00',
#    '2024-09-26T21:00',
#    '2024-09-26T22:00',
#    '2024-09-26T23:00',
#    '2024-09-27T00:00',
#    '2024-09-27T01:00',
#    '2024-09-27T02:00',
#    '2024-09-27T03:00',
# ...

# %%
# Create Data Frame
df = pd.DataFrame()

# Show list time and temperature by data
df['time'] = data['hourly']['time']
df['temperature'] = data['hourly']['temperature_2m']
df
# Out:
#                  time  temperature
# 0    2024-09-26T00:00         14.3
# 1    2024-09-26T01:00         14.4
# 2    2024-09-26T02:00         14.4
# 3    2024-09-26T03:00         14.4
# 4    2024-09-26T04:00         14.2
# ..                ...          ...
# 163  2024-10-02T19:00         14.7
# 164  2024-10-02T20:00         14.8
# 165  2024-10-02T21:00         14.8
# 166  2024-10-02T22:00         14.7
# 167  2024-10-02T23:00         14.6
#
# [168 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time         168 non-null    object
#  1   temperature  168 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.8+ KB

# %%
# Transform date
df['time'] = pd.to_datetime(df['time'], format='%Y-%m-%dT%H:%M')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time         168 non-null    datetime64[ns]
#  1   temperature  168 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.8 KB

# %%
df.sample(5)
# Out:
#                    time  temperature
# 66  2024-09-28 18:00:00         11.8
# 136 2024-10-01 16:00:00         14.9
# 103 2024-09-30 07:00:00          7.7
# 137 2024-10-01 17:00:00         14.3
# 77  2024-09-29 05:00:00          5.6

# %%
load_dotenv()
# Out:
# True

# %%
# Connect
con = spotipy.Spotify(auth_manager= SpotifyClientCredentials(client_id= os.environ.get('CLIENT_ID'), client_secret= os.environ.get('CLIENT_SECRET')))

# %%
# Verify
con

# %%
artist_id = '3TVXtAsR1Inumwj472S9r4'
response_1 = con.artist_top_tracks(artist_id)
if response_1:
    tracks = response_1['tracks']
tracks
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
# ...

# %%
tracks_clean = [{k: (v/(1000*60))%60 if k == 'duration_ms' else v for k, v in track.items() if k in ['name', 'popularity', 'duration_ms']} for track in tracks]

# %%
tracks_clean
# Out:
# [{'duration_ms': 2.899766666666667, 'name': 'One Dance', 'popularity': 87},
#  {'duration_ms': 3.1648833333333335,
#   'name': 'WAIT FOR U (feat. Drake & Tems)',
#   'popularity': 84},
#  {'duration_ms': 4.633333333333334,
#   'name': "It's Up (feat. Young Thug & 21 Savage)",
#   'popularity': 79},
#  {'duration_ms': 3.3162166666666666, 'name': "God's Plan", 'popularity': 82},
#  {'duration_ms': 3.6394,
#   'name': 'Jimmy Cooks (feat. 21 Savage)',
#   'popularity': 82},
#  {'duration_ms': 4.982333333333333, 'name': 'Passionfruit', 'popularity': 81},
#  {'duration_ms': 2.105933333333333,
#   'name': 'Circadian Rhythm',
#   'popularity': 81},
#  {'duration_ms': 2.2857, 'name': 'No Face', 'popularity': 81},
#  {'duration_ms': 5.31985,
#   'name': 'Rich Baby Daddy (feat. Sexyy Red & SZA)',
#   'popularity': 80},
#  {'duration_ms': 4.852916666666666,
#   'name': 'Fair Trade (with Travis Scott)',
#   'popularity': 79}]

# %%
tracks_clean[0]['duration_ms']
# Out:
# 2.899766666666667

# %%
# Convert in Data Frame
df1 = pd.DataFrame([{k: v for k, v in d.items()} for d in tracks_clean])
df1
# Out:
#    duration_ms                                     name  popularity
# 0     2.899767                                One Dance          87
# 1     3.164883          WAIT FOR U (feat. Drake & Tems)          84
# 2     4.633333   It's Up (feat. Young Thug & 21 Savage)          79
# 3     3.316217                               God's Plan          82
# 4     3.639400            Jimmy Cooks (feat. 21 Savage)          82
# 5     4.982333                             Passionfruit          81
# 6     2.105933                         Circadian Rhythm          81
# 7     2.285700                                  No Face          81
# 8     5.319850  Rich Baby Daddy (feat. Sexyy Red & SZA)          80
# 9     4.852917           Fair Trade (with Travis Scott)          79
